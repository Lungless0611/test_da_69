# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [2, 4, 6, 8, 10]
y = [12, 14, 16, 18, 20]

df = pd.DataFrame(x, y)
df
# Out:
#      0
# 12   2
# 14   4
# 16   6
# 18   8
# 20  10

# %%
plt.title('Gráfico que representa... No se que representa, \n pero funciona, y eso es lo que importa', fontfamily="Baby Girly Script")
plt.scatter(x, y)
plt.grid(True)
plt.show()
